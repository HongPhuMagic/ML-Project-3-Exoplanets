# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

keplar = pd.read_csv('cumulative_2020.08.31_09.15.50.csv')

# %%
keplar.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  ...  \
# 0      1.000              0              0              0              0  ...
# 1      0.969              0              0              0              0  ...
# 2      0.000              0              0              0              0  ...
# 3      0.000              0              1              0              0  ...
# 4      1.000              0              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
df = keplar.loc[keplar['koi_disposition'] == 'CANDIDATE']
df
# Out:
#          kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# 2     10811496  K00753.01         NaN       CANDIDATE        CANDIDATE
# 37    11138155  K00760.01         NaN       CANDIDATE        CANDIDATE
# 58    11818800  K00777.01         NaN       CANDIDATE        CANDIDATE
# 62    11918099  K00780.02         NaN       CANDIDATE        CANDIDATE
# 63     9579641  K00115.03         NaN       CANDIDATE        CANDIDATE
# ...        ...        ...         ...             ...              ...
# 9538   9938836  K07978.01         NaN       CANDIDATE        CANDIDATE
# 9542  10011213  K07982.01         NaN       CANDIDATE        CANDIDATE
# 9552  10028127  K08193.01         NaN       CANDIDATE        CANDIDATE
# 9560  10128825  K07986.01         NaN       CANDIDATE        CANDIDATE
# 9562  10155286  K07988.01         NaN       CANDIDATE        CANDIDATE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %%
df2 = keplar[keplar.koi_disposition != 'CANDIDATE']

# %%
df2
# Out:
#          kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0     10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1     10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 3     10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4     10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# 5     10872983  K00756.01  Kepler-228 d       CONFIRMED        CANDIDATE
# ...        ...        ...           ...             ...              ...
# 9557  10205598  K08198.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9558  10031643  K07984.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9559  10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9561  10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9563  10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %%
df3 = keplar[keplar.koi_disposition == 'CANDIDATE']

# %%
df3
# Out:
#          kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# 2     10811496  K00753.01         NaN       CANDIDATE        CANDIDATE
# 37    11138155  K00760.01         NaN       CANDIDATE        CANDIDATE
# 58    11818800  K00777.01         NaN       CANDIDATE        CANDIDATE
# 62    11918099  K00780.02         NaN       CANDIDATE        CANDIDATE
# 63     9579641  K00115.03         NaN       CANDIDATE        CANDIDATE
# ...        ...        ...         ...             ...              ...
# 9538   9938836  K07978.01         NaN       CANDIDATE        CANDIDATE
# 9542  10011213  K07982.01         NaN       CANDIDATE        CANDIDATE
# 9552  10028127  K08193.01         NaN       CANDIDATE        CANDIDATE
# 9560  10128825  K07986.01         NaN       CANDIDATE        CANDIDATE
# 9562  10155286  K07988.01         NaN       CANDIDATE        CANDIDATE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...
